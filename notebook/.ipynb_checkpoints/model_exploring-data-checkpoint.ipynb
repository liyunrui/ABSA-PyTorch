# %%
import torch
import sys
import pandas as pd
pd.options.display.max_colwidth = 500
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
# sys.path.append('../')
# from data_utils import ABSADataset

# %% [markdown]
# # loading dataset

# %%
from torch.utils.data import Dataset

class ABSADataset(Dataset):
    def __init__(self, fname, tokenizer):
        """
        loading dataset
        
        fname: data_path
        
        tokenizer must have function called text_to_sequence
        """
        fin = open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
        lines = fin.readlines()
        fin.close()

        all_data = []
        for i in range(0, len(lines), 3):
            #print ('one-single-line : ',lines[i])
            text_left, _, text_right = [s.lower().strip() for s in lines[i].partition("$T$")]
            print ('text_left : ',text_left)
            print ('text_right : ',text_right)
            aspect = lines[i + 1].lower().strip()
            print ('aspect : ',aspect)
            polarity = lines[i + 2].strip()
            print ('polarity : ', polarity)
            text_raw_indices = tokenizer.text_to_sequence(text_left + " " + aspect + " " + text_right)
            #print ('text_raw_indices', tokenizer.tokenizer.convert_ids_to_tokens(text_raw_indices))
            text_raw_without_aspect_indices = tokenizer.text_to_sequence(text_left + " " + text_right)
            #print ('text_raw_without_aspect_indices', tokenizer.tokenizer.convert_ids_to_tokens(text_raw_without_aspect_indices))

            text_left_indices = tokenizer.text_to_sequence(text_left)
            text_left_with_aspect_indices = tokenizer.text_to_sequence(text_left + " " + aspect)
            text_right_indices = tokenizer.text_to_sequence(text_right, reverse=True)
            text_right_with_aspect_indices = tokenizer.text_to_sequence(" " + aspect + " " + text_right, reverse=True)
            aspect_indices = tokenizer.text_to_sequence(aspect)
            left_context_len = np.sum(text_left_indices != 0)
            aspect_len = np.sum(aspect_indices != 0)
            aspect_in_text = torch.tensor([left_context_len.item(), (left_context_len + aspect_len - 1).item()])
            polarity = int(polarity) + 1

            text_bert_indices = tokenizer.text_to_sequence('[CLS] ' + text_left + " " + aspect + " " + text_right + ' [SEP] ' + aspect + " [SEP]")
            bert_segments_ids = np.asarray([0] * (np.sum(text_raw_indices != 0) + 2) + [1] * (aspect_len + 1))
            bert_segments_ids = pad_and_truncate(bert_segments_ids, tokenizer.max_seq_len)

            text_raw_bert_indices = tokenizer.text_to_sequence("[CLS] " + text_left + " " + aspect + " " + text_right + " [SEP]")
            aspect_bert_indices = tokenizer.text_to_sequence("[CLS] " + aspect + " [SEP]")

            data = {
                'text_bert_indices': text_bert_indices,
                'bert_segments_ids': bert_segments_ids,
                'text_raw_bert_indices': text_raw_bert_indices,
                'aspect_bert_indices': aspect_bert_indices,
                'text_raw_indices': text_raw_indices,
                'text_raw_without_aspect_indices': text_raw_without_aspect_indices,
                'text_left_indices': text_left_indices,
                'text_left_with_aspect_indices': text_left_with_aspect_indices,
                'text_right_indices': text_right_indices,
                'text_right_with_aspect_indices': text_right_with_aspect_indices,
                'aspect_indices': aspect_indices,
                'aspect_in_text': aspect_in_text, # aspect_in_text needed aspect shoule be in the text
                'polarity': polarity,
            }

            all_data.append(data)
        self.data = all_data # list of dict
        
    def get_dataframe(self, tokenizer):
        """
        Conver dataset into DataFrame(Pandas)
        """
        df = []
        columns_name = []
        for i in range(len(self.data)):
            tmp = []
            for k, v in self.data[i].items():
                try:
                    to_str = " ".join(tokenizer.tokenizer.convert_ids_to_tokens(v))
                    #print (to_str)
                    tmp.append(to_str)
                except:
                    if k == 'aspect_in_text':
                        # it's a 1-D tensor wtih shape of (2,), representing the start and end index of the aspect
                        v = v.numpy()  # 1-D tensor
                        #print (v.shape)
                    tmp.append(v)
                if i <= 0:
                    columns_name.append(k)
            df.append(tmp)
        df = pd.DataFrame(df,columns=columns_name)   
        return df
        
    def __getitem__(self, index):
        return self.data[index]

    def __len__(self):
        return len(self.data)

dataset_files = {
'twitter': {
    'train': './datasets/acl-14-short-data/train.raw',
    'test': './datasets/acl-14-short-data/test.raw'
},
'restaurant': {
    'train': './datasets/semeval14/Restaurants_Train.xml.seg',
    'test': './datasets/semeval14/Restaurants_Test_Gold.xml.seg'
},
'laptop': {
    'train': '../datasets/semeval14/Laptops_Train.xml.seg',
    'test': '../datasets/semeval14/Laptops_Test_Gold.xml.seg'
},
'headphone':{
    "train":"../datasets/headphone/headphone_train.txt",
    "test":"../datasets/headphone/headphone_test.txt"
    
}
}

# tokenizer

from pytorch_pretrained_bert import BertTokenizer
import numpy as np

def pad_and_truncate(sequence, maxlen, dtype='int64', padding='post', truncating='post', value=0):
    """
    padding: post means pad with '[PAD]'(BERT) in the last of sentence.
    """
    x = (np.ones(maxlen) * value).astype(dtype)
    if truncating == 'pre':
        trunc = sequence[-maxlen:]
    else:
        trunc = sequence[:maxlen]
    trunc = np.asarray(trunc, dtype=dtype)
    if padding == 'post':
        x[:len(trunc)] = trunc
    else:
        x[-len(trunc):] = trunc
    return x

class Tokenizer4Bert:
    def __init__(self, max_seq_len, pretrained_bert_name = "bert-base-uncased"):
        self.tokenizer = BertTokenizer.from_pretrained(pretrained_bert_name)
        self.max_seq_len = max_seq_len

    def text_to_sequence(self, text, reverse=False, padding='post', truncating='post'):
        ls_tokens = self.tokenizer.tokenize(text)
        sequence = self.tokenizer.convert_tokens_to_ids(ls_tokens)
        if len(sequence) == 0:
            sequence = [0]
        if reverse:
            sequence = sequence[::-1]
        return pad_and_truncate(sequence, self.max_seq_len, padding=padding, truncating=truncating)

# path
train_path = dataset_files['laptop']['train']
test_path = dataset_files['laptop']['test']

# paras 
max_seq_len = 80
pretrained_bert_name = "bert-base-uncased"
tokenizer = Tokenizer4Bert(max_seq_len, pretrained_bert_name)

trainset = ABSADataset(train_path, tokenizer)
testset = ABSADataset(test_path, tokenizer)
print ('number of traning data', len(trainset))
print ('number of testing data', len(testset))
# Out:
# text_left :  i charge it at night and skip taking the
# text_right :  with me because of the good battery life .
# aspect :  cord
# polarity :  0
# text_left :  i charge it at night and skip taking the cord with me because of the good
# text_right :  .
# aspect :  battery life
# polarity :  1
# text_left :  the tech guy then said the
# text_right :  does not do 1-to-1 exchange and i have to direct my concern to the `` sales '' team , which is the retail shop which i bought my netbook from .
# aspect :  service center
# polarity :  -1
# text_left :  the tech guy then said the service center does not do 1-to-1 exchange and i have to direct my concern to the
# text_right :  , which is the retail shop which i bought my netbook from .
# aspect :  "sales" team
# polarity :  -1
# text_left :  the
# text_right :  then said the service center does not do 1-to-1 exchange and i have to direct my concern to the `` sales '' team , which is the retail shop which i bought my netbook from .
# aspect :  tech guy
# polarity :  0
# text_left :  it is of high
# text_right :  , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# aspect :  quality
# polarity :  1
# text_left :  it is of high quality , has a killer
# text_right :  , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to use , and is absolutely gorgeous .
# aspect :  gui
# polarity :  1
# text_left :  it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good
# text_right :  , is easy to use , and is absolutely gorgeous .
# aspect :  applications
# polarity :  1
# text_left :  it is of high quality , has a killer gui , is extremely stable , is highly expandable , is bundled with lots of very good applications , is easy to
# text_right :  , and is absolutely gorgeous .
# aspect :  use
# polarity :  1
# text_left :  easy to
# text_right :  and does not overheat as much as other laptops .
# aspect :  start up
# polarity :  1
# text_left :  i even got my teenage son one , because of the
# text_right :  that it offers , like , ichat , photobooth , garage band and more !
# aspect :  features
# polarity :  1
# text_left :  i even got my teenage son one , because of the features that it offers , like ,
# text_right :  , photobooth , garage band and more !
# aspect :  ichat
# polarity :  1
# text_left :  i even got my teenage son one , because of the features that it offers , like , ichat ,
# text_right :  , garage band and more !
# aspect :  photobooth
# polarity :  1
# text_left :  i even got my teenage son one , because of the features that it offers , like , ichat , photobooth ,
# text_right :  and more !
# aspect :  garage band
# polarity :  1
# text_left :  great laptop that offers many great
# text_right :  !
# aspect :  features
# polarity :  1
# text_left :  one night i turned the freaking thing off after using it , the next day i turn it on , no
# text_right :  , screen all dark , power light steady , hard drive light steady and not flashing as it usually does .
# aspect :  gui
# polarity :  -1
# text_left :  one night i turned the freaking thing off after using it , the next day i turn it on , no gui ,
# text_right :  all dark , power light steady , hard drive light steady and not flashing as it usually does .
# aspect :  screen
# polarity :  -1
# text_left :  one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark ,
# text_right :  steady , hard drive light steady and not flashing as it usually does .
# aspect :  power light
# polarity :  0
# text_left :  one night i turned the freaking thing off after using it , the next day i turn it on , no gui , screen all dark , power light steady ,
# text_right :  t steady and not flashing as it usually does .
# aspect :  hard drive ligh
# polarity :  -1
# text_left :  my only disappointment with the 13 '' model is that they 're the only ones in the macbook pro line up without an i5 or i7
# text_right :  and dual graphics cards , however the trade-off is that you achieve a longer battery life -lrb- of about 2 more hours -rrb- .
# aspect :  processor
# polarity :  -1
# text_left :  my only disappointment with the 13 '' model is that they 're the only ones in the macbook pro line up without an i5 or i7 processor and dual
# text_right :  , however the trade-off is that you achieve a longer battery life -lrb- of about 2 more hours -rrb- .
# aspect :  graphics cards
# polarity :  -1
# text_left :  my only disappointment with the 13 '' model is that they 're the only ones in the macbook pro line up without an i5 or i7 processor and dual graphics cards , however the trade-off is that you achieve a longer
# text_right :  -lrb- of about 2 more hours -rrb- .
# aspect :  battery life
# polarity :  1
# text_left :  i took it back for an asus and same thing - blue screen which required me to remove the
# text_right :  to reset .
# aspect :  battery
# polarity :  0
# text_left :  in the shop , these macbooks are encased in a soft
# text_right :  - so you will never know about the razor edge until you buy it , get it home , break the seal and use it -lrb- very clever con -rrb- .
# aspect :  rubber enclosure
# polarity :  1
# text_left :  in the shop , these macbooks are encased in a soft rubber enclosure - so you will never know about the razor
# text_right :  until you buy it , get it home , break the seal and use it -lrb- very clever con -rrb- .
# aspect :  edge
# polarity :  -1
# text_left :  however , the
# text_right :  and large tracking area make having an external mouse unnecessary -lrb- unless you 're gaming -rrb- .
# aspect :  multi-touch gestures
# polarity :  1
# text_left :  however , the multi-touch gestures and large
# text_right :  make having an external mouse unnecessary -lrb- unless you 're gaming -rrb- .
# aspect :  tracking area
# polarity :  1
# text_left :  however , the multi-touch gestures and large tracking area make having an
# text_right :  unnecessary -lrb- unless you 're gaming -rrb- .
# aspect :  external mouse
# polarity :  0
# text_left :  however , the multi-touch gestures and large tracking area make having an external mouse unnecessary -lrb- unless you 're
# text_right :  -rrb- .
# aspect :  gaming
# polarity :  0
# text_left :  i love the way the entire
# text_right :  works together .
# aspect :  suite of software
# polarity :  1
# text_left :  the
# text_right :  is incredible and i am more than satisfied .
# aspect :  speed
# polarity :  1
# text_left :  this laptop meets every expectation and
# text_right :  is great !
# aspect :  windows 7
# polarity :  1
# text_left :  i can barely use any
# text_right :  because they will not stay connected properly .
# aspect :  usb devices
# polarity :  -1
# text_left :  when i finally had everything running with all my
# text_right :  installed i plugged in my droid to recharge and the system crashed .
# aspect :  software
# polarity :  0
# text_left :  when i finally had everything running with all my software installed i plugged in my droid to recharge and the
# text_right :  crashed .
# aspect :  system
# polarity :  -1
# text_left :  one suggestion i do have , is to not bother getting
# text_right :  expecting it will work just like you knew it to on a pc .
# aspect :  microsoft office for the mac
# polarity :  -1
# text_left :  pairing it with an iphone is a pure pleasure - talk about painless
# text_right :  - used to take me forever - now it 's a snap .
# aspect :  syncing
# polarity :  1
# text_left :  i also got the added bonus of a
# text_right :  , which really helps to extend my screen and keep my eyes fresh !
# aspect :  30" hd monitor
# polarity :  1
# text_left :  i also got the added bonus of a 30 '' hd monitor , which really helps to extend my
# text_right :  and keep my eyes fresh !
# aspect :  screen
# polarity :  0
# text_left :  the machine is slow to
# text_right :  and occasionally crashes completely .
# aspect :  boot up
# polarity :  -1
# text_left :  after paying several hundred dollars for this
# text_right :  , it is frustrating that you can not get help after hours .
# aspect :  service
# polarity :  -1
# text_left :  i love the
# text_right :  and the preloaded software .
# aspect :  operating system
# polarity :  1
# text_left :  i love the operating system and the
# text_right :  .
# aspect :  preloaded software
# polarity :  1
# text_left :  the best thing about this laptop is the
# text_right :  along with some of the newer features .
# aspect :  price
# polarity :  1
# text_left :  the best thing about this laptop is the price along with some of the newer
# text_right :  .
# aspect :  features
# polarity :  1
# text_left :  after numerous attempts of trying -lrb- including setting the
# text_right :  directly -rrb- , i gave up -lrb- i am a techie -rrb- .
# aspect :  clock in bios setup
# polarity :  -1
# text_left :  you will not be able to talk to an american
# text_right :  is out of country .
# aspect :  warranty service
# polarity :  -1
# text_left :  but now i have realized its a problem with this
# text_right :  .
# aspect :  brand
# polarity :  -1
# text_left :  i sent it back to toshiba twice they covered it under the
# text_right :  .
# aspect :  warranty
# polarity :  1
# text_left :  i was looking for a mac which is portable and has all the
# text_right :  that i was looking for .
# aspect :  features
# polarity :  1
# text_left :  also kinda loud when the
# text_right :  was running .
# aspect :  fan
# polarity :  -1
# text_left :  in desparation , i called their
# text_right :  and was told that my warranty had expired -lrb- 2 days old -rrb- and that the priviledge of talking to a technician would cost me -lrb- `` have your credit card ready '' -rrb- .
# aspect :  customer service number
# polarity :  0
# text_left :  in desparation , i called their customer service number and was told that my
# text_right :  had expired -lrb- 2 days old -rrb- and that the priviledge of talking to a technician would cost me -lrb- `` have your credit card ready '' -rrb- .
# aspect :  warranty
# polarity :  -1
# text_left :  in desparation , i called their customer service number and was told that my warranty had expired -lrb- 2 days old -rrb- and that the priviledge of
# text_right :  would cost me -lrb- `` have your credit card ready '' -rrb- .
# aspect :  talking to a technician
# polarity :  -1
# text_left :  there also seemed to be a problem with the
# text_right :  as certain times windows loads but claims to not be able to find any drivers or files .
# aspect :  hard disc
# polarity :  -1
# text_left :  there also seemed to be a problem with the hard disc as certain times
# text_right :  loads but claims to not be able to find any drivers or files .
# aspect :  windows
# polarity :  -1
# text_left :  there also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any
# text_right :  or files .
# aspect :  drivers
# polarity :  0
# text_left :
# text_right :  updated ok but the bios update froze the system up and the computer shut down .
# aspect :  drivers
# polarity :  1
# text_left :  drivers updated ok but the
# text_right :  froze the system up and the computer shut down .
# aspect :  bios update
# polarity :  -1
# text_left :  drivers updated ok but the bios update froze the
# text_right :  up and the computer shut down .
# aspect :  system
# polarity :  -1
# text_left :  spent 2 hours on phone with
# text_right :  .
# aspect :  hp technical support
# polarity :  0
# text_left :  speaking of the
# text_right :  , it too has problems .
# aspect :  browser
# polarity :  -1
# text_left :  the
# text_right :  is too slick .
# aspect :  keyboard
# polarity :  -1
# text_left :  nightly my computer defrags itself and runs a
# text_right :  .
# aspect :  virus scan
# polarity :  0
# text_left :  it 's like
# text_right :  , but if you can look past it , it 's great !
# aspect :  9 punds
# polarity :  -1
# text_left :  it 's just as fast with one
# text_right :  open as it is with sixteen open .
# aspect :  program
# polarity :  0
# text_left :  still under
# text_right :  so called toshiba , no help at all .
# aspect :  warrenty
# polarity :  -1
# text_left :  i was happy with my purchase of a toshiba satellite l305d-s5934 laptop until it came time to have it repaired under the
# text_right :  .
# aspect :  toshiba warranty
# polarity :  -1
# text_left :  amazing
# text_right :  !
# aspect :  quality
# polarity :  1
# text_left :  the fact that you can spend over $ 100 on just a
# text_right :  underscores the value of this machine .
# aspect :  webcam
# polarity :  0
# text_left :  the fact that you can spend over $ 100 on just a webcam underscores the
# text_right :  of this machine .
# aspect :  value
# polarity :  1
# text_left :  i mainly use it for email ,
# text_right :  , and managing personal files -lrb- pics , vids , etc. -rrb- .
# aspect :  internet
# polarity :  0
# text_left :  i mainly use it for email , internet , and
# text_right :  -lrb- pics , vids , etc. -rrb- .
# aspect :  managing personal files
# polarity :  0
# text_left :  a month or so ago , the freaking
# text_right :  just died .
# aspect :  motherboard
# polarity :  -1
# text_left :  the
# text_right :  it comes with does not work properly , so when trying to fix the problems with it it started not working at all .
# aspect :  system
# polarity :  -1
# text_left :  then after 4 or so months the
# text_right :  stopped working so i was forced to go out and buy new hardware just to keep this computer running .
# aspect :  charger
# polarity :  -1
# text_left :  then after 4 or so months the charger stopped working so i was forced to go out and buy new
# text_right :  just to keep this computer running .
# aspect :  hardware
# polarity :  -1
# text_left :  if a website ever freezes -lrb- which is rare -rrb- , its really easy to
# text_right :  .
# aspect :  force quit
# polarity :  1
# text_left :  it rarely
# text_right :  and when it does it 's incredibly slow .
# aspect :  works
# polarity :  -1
# text_left :  i also enjoy the fact that my macbook pro laptop allows me to run
# text_right :  on it by using the vmware program .
# aspect :  windows 7
# polarity :  1
# text_left :  i also enjoy the fact that my macbook pro laptop allows me to run windows 7 on it by using the
# text_right :  .
# aspect :  vmware program
# polarity :  0
# text_left :  it 's so much easier to navigate through the
# text_right :  , to find files , and it runs a lot faster !
# aspect :  operating system
# polarity :  1
# text_left :  it 's so much easier to navigate through the operating system , to find files , and it
# text_right :  a lot faster !
# aspect :  runs
# polarity :  1
# text_left :  it 's so much easier to
# text_right :  through the operating system , to find files , and it runs a lot faster !
# aspect :  navigate
# polarity :  1
# text_left :  it 's so much easier to navigate through the operating system , to
# text_right :  , and it runs a lot faster !
# aspect :  find files
# polarity :  1
# text_left :  purchased a toshiba lap top it worked good until just after the
# text_right :  went out .
# aspect :  warrenty
# polarity :  -1
# text_left :  i wanted to purchase the
# text_right :  and they refused , because they knew it was trouble .
# aspect :  extended warranty
# polarity :  0
# text_left :  we upgraded the
# text_right :  to four gigabytes in order to take advantage of the performace increase in speed .
# aspect :  memory
# polarity :  0
# text_left :  we upgraded the memory to four gigabytes in order to take advantage of the performace increase in
# text_right :  .
# aspect :  speed
# polarity :  1
# text_left :  we upgraded the memory to four gigabytes in order to take advantage of the
# text_right :  increase in speed .
# aspect :  performace
# polarity :  1
# text_left :  the reality was , it heated up very quickly , and took way too long to do simple things , like
# text_right :  .
# aspect :  opening my documents folder
# polarity :  -1
# text_left :  i had always used pcs and been constantly frustrated by the crashing and the poorly designed
# text_right :  that were never very intuitive .
# aspect :  operating systems
# polarity :  -1
# text_left :  then , within 5 months , the
# text_right :  crapped out on me .
# aspect :  charger
# polarity :  -1
# text_left :  and if you have a iphone or ipod touch you can connect and download songs to it at high
# text_right :  .
# aspect :  speed
# polarity :  1
# text_left :  i love the
# text_right :  .
# aspect :  glass touchpad
# polarity :  1
# text_left :  i continued to take the computer in again and they replaced the
# text_right :  and mother board yet again .
# aspect :  hard drive
# polarity :  -1
# text_left :  i continued to take the computer in again and they replaced the hard drive and
# text_right :  yet again .
# aspect :  mother board
# polarity :  -1
# text_left :  i am using the
# text_right :  - sound is good .
# aspect :  external speaker
# polarity :  1
# text_left :  i am using the external speaker -
# text_right :  is good .
# aspect :  sound
# polarity :  1
# text_left :  still testing the
# text_right :  as i thought it would be better , but am very happy with the upgrade .
# aspect :  battery life
# polarity :  -1
# text_left :  then hp sends it back to me with the
# text_right :  screwed up , not able to connect .
# aspect :  hardware
# polarity :  -1
# text_left :  oh yeah , do n't forget the expensive
# text_right :  to and from hp .
# aspect :  shipping
# polarity :  -1
# text_left :  everything is so easy to use ,
# text_right :  is just so much simpler than microsoft software .
# aspect :  mac software
# polarity :  1
# text_left :  everything is so easy to use , mac software is just so much simpler than
# text_right :  .
# aspect :  microsoft software
# polarity :  -1
# text_left :  everything is so easy to
# text_right :  , mac software is just so much simpler than microsoft software .
# aspect :  use
# polarity :  1
# text_left :  and if you do a lot of writing , editing is a problem since there is no forward
# text_right :  .
# aspect :  delete  key
# polarity :  -1
# text_left :  and if you do a lot of writing ,
# text_right :  is a problem since there is no forward delete key .
# aspect :  editing
# polarity :  -1
# text_left :  its ease of
# text_right :  and the top service from apple - be it their phone assistance or bellying up to the genius bar - can not be beat .
# aspect :  use
# polarity :  1
# text_left :  its ease of use and the top
# text_right :  from apple - be it their phone assistance or bellying up to the genius bar - can not be beat .
# aspect :  service
# polarity :  1
# text_left :  its ease of use and the top service from apple - be it their
# text_right :  or bellying up to the genius bar - can not be beat .
# aspect :  phone assistance
# polarity :  1
# text_left :  its ease of use and the top service from apple - be it their phone assistance or bellying up to the
# text_right :  - can not be beat .
# aspect :  genius bar
# polarity :  1
# text_left :  it has a 10 hour
# text_right :  when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# aspect :  battery life
# polarity :  1
# text_left :  it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a
# text_right :  of just over 5 hours .
# aspect :  battery life
# polarity :  1
# text_left :  it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of
# text_right :  and movie playing it 'll have a battery life of just over 5 hours .
# aspect :  gaming
# polarity :  0
# text_left :  it has a 10 hour battery life when you 're doing web browsing and word editing , making it perfect for the classroom or office , and in terms of gaming and
# text_right :  it 'll have a battery life of just over 5 hours .
# aspect :  movie playing
# polarity :  0
# text_left :  it has a 10 hour battery life when you 're doing
# text_right :  and word editing , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# aspect :  web browsing
# polarity :  0
# text_left :  it has a 10 hour battery life when you 're doing web browsing and
# text_right :  , making it perfect for the classroom or office , and in terms of gaming and movie playing it 'll have a battery life of just over 5 hours .
# aspect :  word editing
# polarity :  0
# text_left :  acer has set me up with free
# text_right :  , when they are available since i asked .
# aspect :  recovery discs
# polarity :  1
# text_left :  i also purchased
# text_right :  with the `` no lemon '' clause .
# aspect :  office max's "max assurance"
# polarity :  0
# text_left :  i eventually did the migration from my
# text_right :  which uses usb .
# aspect :  imac backup disc
# polarity :  0
# text_left :  i eventually did the migration from my imac backup disc which uses
# text_right :  .
# aspect :  usb
# polarity :  0
# text_left :  the
# text_right :  seems to be very good , and have had no issues with it .
# aspect :  battery life
# polarity :  1
# text_left :  enabling the
# text_right :  is useless .
# aspect :  battery timer
# polarity :  -1
# text_left :
# text_right :  on the outside were alright but i did not track in core processing unit temperatures .
# aspect :  temperatures
# polarity :  0
# text_left :  temperatures on the outside were alright but i did not track in
# text_right :  .
# aspect :  core processing unit temperatures
# polarity :  0
# text_left :  going to bring it to
# text_right :  today .
# aspect :  service
# polarity :  0
# text_left :  there is no need to purchase
# text_right :  , which saves me a lot of time and money .
# aspect :  virus protection for mac
# polarity :  1
# text_left :  but we had paid for
# text_right :  , and there was none .
# aspect :  bluetooth
# polarity :  -1
# text_left :  so , i paid a visit to
# text_right :  at alexandra road , hoping they can make the hinge tighter .
# aspect :  lg notebook service center
# polarity :  0
# text_left :  so , i paid a visit to lg notebook service center at alexandra road , hoping they can make the
# text_right :  tighter .
# aspect :  hinge
# polarity :  -1
# text_left :  my daughter uses it for
# text_right :  , email , facebook , pictures and music .
# aspect :  games
# polarity :  0
# text_left :  it is always reliable , never bugged and
# text_right :  well .
# aspect :  responds
# polarity :  1
# text_left :  after about a week i finally got it back and was told that the
# text_right :  had failed and so they installed a new motherboard .
# aspect :  motherboard
# polarity :  -1
# text_left :  after about a week i finally got it back and was told that the motherboard had failed and so they installed a new
# text_right :  .
# aspect :  motherboard
# polarity :  0
# text_left :  it was slow , locked up , and also had
# text_right :  replaced after only 2 months !
# aspect :  hardware
# polarity :  -1
# text_left :  they had to replace the
# text_right :  in april
# aspect :  motherboard
# polarity :  -1
# text_left :  yes , the computer was light weight , less expensive than the average laptop , and was pretty self explantory in
# text_right :  .
# aspect :  use
# polarity :  1
# text_left :  also , if you need to talk to a
# text_right :  , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed system , which most people would have went with xp if they could .
# aspect :  representive at microsoft
# polarity :  -1
# text_left :  also , if you need to talk to a representive at microsoft , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed
# text_right :  , which most people would have went with xp if they could .
# aspect :  system
# polarity :  -1
# text_left :  also , if you need to talk to a representive at microsoft , there is a charge , which i believe is robbery , since you are charged enormous amounts for a very badly designed system , which most people would have went with
# text_right :  if they could .
# aspect :  xp
# polarity :  1
# text_left :  i love
# text_right :  which is a vast improvment over vista .
# aspect :  windows 7
# polarity :  1
# text_left :  i love windows 7 which is a vast improvment over
# text_right :  .
# aspect :  vista
# polarity :  -1
# text_left :
# text_right :  is great , very quiet for all the typing that i do .
# aspect :  keyboard
# polarity :  1
# text_left :
# text_right :  is an insult to it 's customers who pay good money for shoddy products .
# aspect :  dell's customer disservice
# polarity :  -1
# text_left :  it had a
# text_right :  malfunction after 10 minutes of general use , and would not move past this error .
# aspect :  cooling system
# polarity :  -1
# text_left :  it had a cooling system malfunction after 10 minutes of general
# text_right :  , and would not move past this error .
# aspect :  use
# polarity :  0
# text_left :  i can render avchd movies with little effort , which was a problem for most pc 's unless you had a
# text_right :  .
# aspect :  quad core i7
# polarity :  1
# text_left :  after talking it over with the very knowledgeable
# text_right :  , i chose the macbook pro over the white macbook .
# aspect :  sales associate
# polarity :  1
# text_left :  if you really want a bang-up
# text_right :  and do n't need to run windows applications , go with an apple ;
# aspect :  system
# polarity :  1
# text_left :  if you really want a bang-up system and do n't need to run
# text_right :  , go with an apple ;
# aspect :  windows applications
# polarity :  0
# text_left :  you wo n't have to spend gobs of money on some inefficient
# text_right :  that needs to be updated every month and that constantly drains your wallet .
# aspect :  virus program
# polarity :  -1
# text_left :  it
# text_right :  like seven pounds or something like that .
# aspect :  weighed
# polarity :  0
# text_left :  it weighed like
# text_right :  or something like that .
# aspect :  seven pounds
# polarity :  0
# text_left :  2 months later , the
# text_right :  went .
# aspect :  battery
# polarity :  -1
# text_left :  you may need to special order a
# text_right :  .
# aspect :  bag
# polarity :  0
# text_left :  it 's
# text_right :  is even cool .
# aspect :  color
# polarity :  1
# text_left :
# text_right :  are all in weird places and is way too large for the way it is designed .
# aspect :  keys
# polarity :  -1
# text_left :  keys are all in weird places and is way too large for the way it is
# text_right :  .
# aspect :  designed
# polarity :  -1
# text_left :  yes , a mac is much more money than the average laptop out there , but there is no comparison in
# text_right :  , speed and just cool factor .
# aspect :  style
# polarity :  1
# text_left :  yes , a mac is much more money than the average laptop out there , but there is no comparison in style ,
# text_right :  and just cool factor .
# aspect :  speed
# polarity :  1
# text_left :  the
# text_right :  feels good and i type just fine on it .
# aspect :  keyboard
# polarity :  1
# text_left :  i thought the white mac computers looked dirty too quicly where you use the
# text_right :  and where you place your hands when typing .
# aspect :  mousepad
# polarity :  0
# text_left :  and not to mention after using it for a few months or so , the
# text_right :  will slowly less and less hold a charge until you ca n't leave it unplugged for more than 5 minutes without the thing dying .
# aspect :  battery
# polarity :  -1
# text_left :  best buy - 5 stars + + + -lrb-
# text_right :  , service , respect for old men who are n't familiar with the technology -rrb- dell computers - 3 stars dell support - owes a me a couple
# aspect :  sales
# polarity :  1
# text_left :  best buy - 5 stars + + + -lrb- sales ,
# text_right :  , respect for old men who are n't familiar with the technology -rrb- dell computers - 3 stars dell support - owes a me a couple
# aspect :  service
# polarity :  1
# text_left :  best buy - 5 stars + + + -lrb- sales , service , respect for old men who are n't familiar with the technology -rrb- dell computers - 3 stars
# text_right :  - owes a me a couple
# aspect :  dell support
# polarity :  1
# text_left :  no complaints with their desktop , and maybe because it just sits on your desktop , and you do n't carry it around , which could jar the
# text_right :  , or the motherboard .
# aspect :  hard drive
# polarity :  0
# text_left :  no complaints with their desktop , and maybe because it just sits on your desktop , and you do n't carry it around , which could jar the hard drive , or the
# text_right :  .
# aspect :  motherboard
# polarity :  0
# text_left :  yes , they cost more , but they more than make up for it in
# text_right :  , construction quality , and longevity .
# aspect :  speed
# polarity :  1
# text_left :  yes , they cost more , but they more than make up for it in speed ,
# text_right :  , and longevity .
# aspect :  construction quality
# polarity :  1
# text_left :  yes , they cost more , but they more than make up for it in speed , construction quality , and
# text_right :  .
# aspect :  longevity
# polarity :  1
# text_left :  since i keyboard over 100 wpm , i look for a unit that has a comfortble
# text_right :  -lrb- no keys sticking or lagging , strange configuration of `` extra key '' , etc. .
# aspect :  keyboard
# polarity :  1
# text_left :  since i keyboard over 100 wpm , i look for a unit that has a comfortble keyboard -lrb- no
# text_right :  sticking or lagging , strange configuration of `` extra key '' , etc. .
# aspect :  keys
# polarity :  1
# text_left :  since i keyboard over 100 wpm , i look for a unit that has a comfortble keyboard -lrb- no keys sticking or lagging , strange
# text_right :  , etc. .
# aspect :  configuration of "extra key"
# polarity :  1
# text_left :  -rrb- i also tried the
# text_right :  and compared it to other netbooks in the store .
# aspect :  touch pad
# polarity :  0
# text_left :  it absolutely is more expensive than most pc laptops , but the ease of
# text_right :  , security , and minimal problems that have arisen make it well worth the pricetag .
# aspect :  use
# polarity :  1
# text_left :  it absolutely is more expensive than most pc laptops , but the ease of use ,
# text_right :  , and minimal problems that have arisen make it well worth the pricetag .
# aspect :  security
# polarity :  1
# text_left :  it gets stuck all of the time you
# text_right :  it , and you have to keep tapping on it to get it to work .
# aspect :  use
# polarity :  -1
# text_left :  it gets stuck all of the time you use it , and you have to keep tapping on it to get it to
# text_right :  .
# aspect :  work
# polarity :  -1
# text_left :  lots of
# text_right :  .
# aspect :  preloaded software
# polarity :  1
# text_left :  i wish it had a
# text_right :  though , then it would be perfect !
# aspect :  webcam
# polarity :  -1
# text_left :  my favorite part of this computer is that it has a
# text_right :  so i can connect it to a bigger screen .
# aspect :  vga port
# polarity :  1
# text_left :  my favorite part of this computer is that it has a vga port so i can connect it to a bigger
# text_right :  .
# aspect :  screen
# polarity :  0
# text_left :  another thing i might add is the
# text_right :  is excellent .
# aspect :  battery life
# polarity :  1
# text_left :  one drawback , i wish the
# text_right :  were backlit .
# aspect :  keys
# polarity :  -1
# text_left :  acer was no help and garmin could not determine the problem -lrb- after spending about 2 hours with me -rrb- , so i returned it and purchased a toshiba r700 that seems even nicer and i was able to load all of my
# text_right :  with no problem .
# aspect :  software
# polarity :  1
# text_left :  i wish the
# text_right :  could be louder and the mouse didnt break after only a month .
# aspect :  volume
# polarity :  -1
# text_left :  i wish the volume could be louder and the
# text_right :  didnt break after only a month .
# aspect :  mouse
# polarity :  -1
# text_left :  i play a lot of casual games online , and the
# text_right :  is very responsive .
# aspect :  touchpad
# polarity :  1
# text_left :  granted , it 's still a very new laptop but in comparison to my previous laptops and desktops , my mac
# text_right :  noticeably quicker .
# aspect :  boots up
# polarity :  1
# text_left :  it caught a virus that completely wiped out my
# text_right :  in a matter of hours .
# aspect :  hard drive
# polarity :  -1
# text_left :  it is everything i 'd hoped it would be from a
# text_right :  , but somehow a bit more sturdy .
# aspect :  look and feel standpoint
# polarity :  1
# text_left :  the only fact i dont like about apples is they generally use
# text_right :  and i dont use safari but after i install mozzilla firfox i love every single bit about it .
# aspect :  safari
# polarity :  -1
# text_left :  the only fact i dont like about apples is they generally use safari and i dont use
# text_right :  but after i install mozzilla firfox i love every single bit about it .
# aspect :  safari
# polarity :  -1
# text_left :  the only fact i dont like about apples is they generally use safari and i dont use safari but after i install
# text_right :  i love every single bit about it .
# aspect :  mozzilla firfox
# polarity :  1
# text_left :  the
# text_right :  was not there at all , and the fingerprint reader driver would be there , but the software would hang after installation was 1/2 way done .
# aspect :  bluetooth
# polarity :  -1
# text_left :  the bluetooth was not there at all , and the
# text_right :  would be there , but the software would hang after installation was 1/2 way done .
# aspect :  fingerprint reader driver
# polarity :  -1
# text_left :  the bluetooth was not there at all , and the fingerprint reader driver would be there , but the
# text_right :  would hang after installation was 1/2 way done .
# aspect :  software
# polarity :  -1
# text_left :  great
# text_right :  , speed , display .
# aspect :  battery
# polarity :  1
# text_left :  great battery ,
# text_right :  , display .
# aspect :  speed
# polarity :  1
# text_left :  great battery , speed ,
# text_right :  .
# aspect :  display
# polarity :  1
# text_left :  the
# text_right :  was fast , and i would not hesitate to purchase this laptop again .
# aspect :  delivery
# polarity :  1
# text_left :  i 've been impressed with the
# text_right :  and the performance for such a small amount of memory .
# aspect :  battery life
# polarity :  1
# text_left :  i 've been impressed with the battery life and the
# text_right :  for such a small amount of memory .
# aspect :  performance
# polarity :  1
# text_left :  i 've been impressed with the battery life and the performance for such a small amount of
# text_right :  .
# aspect :  memory
# polarity :  -1
# text_left :  it 's
# text_right :  are terrific , including the replacements for microsoft office .
# aspect :  applications
# polarity :  1
# text_left :  it 's applications are terrific , including the replacements for
# text_right :  .
# aspect :  microsoft office
# polarity :  1
# text_left :  they improved nothing else such as
# text_right :  , appearance , cooling system , graphics card , etc. .
# aspect :  resolution
# polarity :  -1
# text_left :  they improved nothing else such as resolution ,
# text_right :  , cooling system , graphics card , etc. .
# aspect :  appearance
# polarity :  -1
# text_left :  they improved nothing else such as resolution , appearance ,
# text_right :  , graphics card , etc. .
# aspect :  cooling system
# polarity :  -1
# text_left :  they improved nothing else such as resolution , appearance , cooling system ,
# text_right :  , etc. .
# aspect :  graphics card
# polarity :  -1
# text_left :  i got it back and my
# text_right :  and built-in mic were shorting out anytime i touched the lid , -lrb- mind you this was my means of communication with my fiance who was deployed -rrb- but i suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out .
# aspect :  built-in webcam
# polarity :  -1
# text_left :  i got it back and my built-in webcam and
# text_right :  were shorting out anytime i touched the lid , -lrb- mind you this was my means of communication with my fiance who was deployed -rrb- but i suffered thru it and would constandly have to reset the computer to be able to use my cam and mic anytime they went out .
# aspect :  built-in mic
# polarity :  -1
# text_left :  i got it back and my built-in webcam and built-in mic were shorting out anytime i touched the lid , -lrb- mind you this was my means of communication with my fiance who was deployed -rrb- but i suffered thru it and would constandly have to reset the computer to be able to use my
# text_right :  and mic anytime they went out .
# aspect :  cam
# polarity :  -1
# text_left :  i got it back and my built-in webcam and built-in mic were shorting out anytime i touched the lid , -lrb- mind you this was my means of communication with my fiance who was deployed -rrb- but i suffered thru it and would constandly have to reset the computer to be able to use my cam and
# text_right :  anytime they went out .
# aspect :  mic
# polarity :  -1
# text_left :  is this partially due to the fact that it is running
# text_right :  ?
# aspect :  windows vista
# polarity :  0
# text_left :  the
# text_right :  has a bad connector with the power supply and shortly after warrenty expires the power supply will start having issues .
# aspect :  board
# polarity :  -1
# text_left :  the board has a bad
# text_right :  with the power supply and shortly after warrenty expires the power supply will start having issues .
# aspect :  connector
# polarity :  -1
# text_left :  the board has a bad connector with the
# text_right :  and shortly after warrenty expires the power supply will start having issues .
# aspect :  power supply
# polarity :  -1
# text_left :  the board has a bad connector with the power supply and shortly after
# text_right :  expires the power supply will start having issues .
# aspect :  warrenty
# polarity :  -1
# text_left :  the board has a bad connector with the power supply and shortly after warrenty expires the
# text_right :  will start having issues .
# aspect :  power supply
# polarity :  -1
# text_left :  my dad has one of the very first toshibas ever made , yes its abit slow now but still works well and i hooked to my
# text_right :  !
# aspect :  ethernet
# polarity :  1
# text_left :  my dad has one of the very first toshibas ever made , yes its abit slow now but still
# text_right :  well and i hooked to my ethernet !
# aspect :  works
# polarity :  1
# text_left :  mostly i love the
# text_right :  .
# aspect :  drag and drop feature
# polarity :  1
# text_left :  oh yeah , and if the fancy
# text_right :  breaks guess who you have to send it to to get it fixed ?
# aspect :  webcam
# polarity :  -1
# text_left :  i ordered through macmall , which saved me the
# text_right :  i would have incurred buying locally .
# aspect :  sales tax
# polarity :  1
# text_left :  of course , i also have several great
# text_right :  that came for free including iwork , garageband , and imovie .
# aspect :  software packages
# polarity :  1
# text_left :  of course , i also have several great software packages that came for free including
# text_right :  , garageband , and imovie .
# aspect :  iwork
# polarity :  1
# text_left :  of course , i also have several great software packages that came for free including iwork ,
# text_right :  , and imovie .
# aspect :  garageband
# polarity :  1
# text_left :  of course , i also have several great software packages that came for free including iwork , garageband , and
# text_right :  .
# aspect :  imovie
# polarity :  1
# text_left :  the
# text_right :  is very large and crystal clear with amazing colors and resolution .
# aspect :  screen
# polarity :  1
# text_left :  the screen is very large and crystal clear with amazing
# text_right :  and resolution .
# aspect :  colors
# polarity :  1
# text_left :  the screen is very large and crystal clear with amazing colors and
# text_right :  .
# aspect :  resolution
# polarity :  1
# text_left :  after a little more than a year of owning my macbook pro , the
# text_right :  has completely died .
# aspect :  monitor
# polarity :  -1
# text_left :  the brand of
# text_right :  has just become ingrained in our lexicon now , but keep in mind that apple started it all .
# aspect :  itunes
# polarity :  1
# text_left :
# text_right :  : i know 13 is small -lrb- especially for a desktop replacement -rrb- but with an external monitor , who cares .
# aspect :  size
# polarity :  -1
# text_left :  size : i know 13 is small -lrb- especially for a desktop replacement -rrb- but with an
# text_right :  , who cares .
# aspect :  external monitor
# polarity :  0
# text_left :  additional caveat : the
# text_right :  comes with some toshiba-specific software that may or may not be to a user 's liking .
# aspect :  base installation
# polarity :  -1
# text_left :  additional caveat : the base installation comes with some toshiba-specific
# text_right :  that may or may not be to a user 's liking .
# aspect :  software
# polarity :  -1
# text_left :  taking it back to best buy i found that a tiny plastic piece inside had broken -lrb-
# text_right :  issue -rrb- .
# aspect :  manuf
# polarity :  -1
# text_left :  the
# text_right :  is incredibly bright , much brighter than my powerbook and very crisp .
# aspect :  display
# polarity :  1
# text_left :  the
# text_right :  seems to always perform so much better than intel .
# aspect :  amd turin processor
# polarity :  1
# text_left :  the amd turin processor seems to always perform so much better than
# text_right :  .
# aspect :  intel
# polarity :  -1
# text_left :  after that the said it was under
# text_right :  .
# aspect :  warranty
# polarity :  0
# text_left :  the
# text_right :  is not the easiest thing to navigate due to the stacking .
# aspect :  start menu
# polarity :  -1
# text_left :  the start menu is not the easiest thing to
# text_right :  due to the stacking .
# aspect :  navigate
# polarity :  -1
# text_left :  only thing i would want to add to this is an internal
# text_right :  .
# aspect :  bluray read/write drive
# polarity :  -1
# text_left :  the
# text_right :  said he had tried to duplicate the damage and was n't able to recreate it therefore it had to be their defect .
# aspect :  service tech
# polarity :  -1
# text_left :  the
# text_right :  i purchased this from sent it back , , , , , eventually i got a new or repaired machine approximately 3 weeks later .
# aspect :  tech store
# polarity :  -1
# text_left :  really like the textured
# text_right :  which shows no fingerprints .
# aspect :  surface
# polarity :  1
# text_left :  the
# text_right :  is bright and the keyboard is nice ;
# aspect :  screen
# polarity :  1
# text_left :  the screen is bright and the
# text_right :  is nice ;
# aspect :  keyboard
# polarity :  1
# text_left :  but the machine is awesome and
# text_right :  is great and i love snow leopard x.
# aspect :  ilife
# polarity :  1
# text_left :  but the machine is awesome and ilife is great and i love
# text_right :  .
# aspect :  snow leopard x
# polarity :  1
# text_left :  high
# text_right :  , however .
# aspect :  price tag
# polarity :  -1
# text_left :  i thought learning the
# text_right :  would be hard , but it is easily picked up if you are familiar with a pc .
# aspect :  mac os
# polarity :  1
# text_left :  i had static in the output , and i had to reduce the
# text_right :  to `` fm '' as opposed to the default `` cd .
# aspect :  sound output quality
# polarity :  -1
# text_left :  i custom ordered the machine from hp and could not understand the
# text_right :  due to his accent .
# aspect :  techie
# polarity :  -1
# text_left :  it is easy to
# text_right :  and lightweight .
# aspect :  use
# polarity :  1
# text_left :  i went to
# text_right :  and found some suggestions to fix it .
# aspect :  toshiba online help
# polarity :  1
# text_left :  they also have a longer
# text_right :  than other computers -lrb- i have several friends who still use the older apple powerbooks -rrb- .
# aspect :  service life
# polarity :  1
# text_left :  if you check you will find the same notebook with the above missing
# text_right :  and a dual core amd or intel processor .
# aspect :  ports
# polarity :  0
# text_left :  if you check you will find the same notebook with the above missing ports and a dual core amd or intel
# text_right :  .
# aspect :  processor
# polarity :  0
# text_left :  this laptop is a great
# text_right :  and has a sleek look .
# aspect :  price
# polarity :  1
# text_left :  this laptop is a great price and has a sleek
# text_right :  .
# aspect :  look
# polarity :  1
# text_left :  i especially like the
# text_right :  which has chiclet type keys .
# aspect :  keyboard
# polarity :  1
# text_left :  i especially like the keyboard which has chiclet type
# text_right :  .
# aspect :  keys
# polarity :  1
# text_left :  runs hot i thought we were paying for
# text_right :  in our decision to buy an apple product .
# aspect :  quality
# polarity :  -1
# text_left :  for the not so good , i got the
# text_right :  - which is very glossy .
# aspect :  stock screen
# polarity :  -1
# text_left :  the
# text_right :  was a good choice .
# aspect :  gray color
# polarity :  1
# text_left :  i would like to have
# text_right :  rather than the adjustment that is on the front .
# aspect :  volume buttons
# polarity :  -1
# text_left :  the
# text_right :  a amd semprom at 2.1 ghz is a bummer it does not have the power for hd or heavy computing .
# aspect :  processor
# polarity :  -1
# text_left :  the processor a amd semprom at 2.1 ghz is a bummer it does not have the power for hd or heavy
# text_right :  .
# aspect :  computing
# polarity :  -1
# text_left :  i bought a
# text_right :  for my key pad and it works great : -rrb-
# aspect :  protector
# polarity :  0
# text_left :  i bought a protector for my
# text_right :  and it works great : -rrb-
# aspect :  key pad
# polarity :  1
# text_left :  the
# text_right :  is great -lrb- i even put it to the test by accident -rrb- - excellent innovation !
# aspect :  magnetic plug-in power charging power cord
# polarity :  1
# text_left :  it seems they could have updated
# text_right :  and done without creating vista .
# aspect :  xp
# polarity :  1
# text_left :  it seems they could have updated xp and done without creating
# text_right :  .
# aspect :  vista
# polarity :  -1
# text_left :  it is easy to use , fast and has great
# text_right :  for the money .
# aspect :  graphics
# polarity :  1
# text_left :  it is easy to
# text_right :  , fast and has great graphics for the money .
# aspect :  use
# polarity :  1
# text_left :  i like how the
# text_right :  is so simple and easy to use .
# aspect :  mac os
# polarity :  1
# text_left :  i like how the mac os is so simple and easy to
# text_right :  .
# aspect :  use
# polarity :  1
# text_left :  while apple 's saving grace is the fact that they at least stand behind their products , and their
# text_right :  is great , it would be nice if their products were more reliable to justify the premium .
# aspect :  support
# polarity :  1
# text_left :  i was ready to take it back for a refund , but the
# text_right :  camed through and pointed me in the right direction to get it fixed .
# aspect :  geek squad
# polarity :  1
# text_left :  only good thing is the
# text_right :  .
# aspect :  graphics quality
# polarity :  1
# text_left :  the other lock-up problems are from a myriad of causes , the most common being a corrupted version of
# text_right :  which can render the browser useless .
# aspect :  appleworks
# polarity :  -1
# text_left :  the other lock-up problems are from a myriad of causes , the most common being a corrupted version of appleworks which can render the
# text_right :  useless .
# aspect :  browser
# polarity :  -1
# text_left :  the
# text_right :  wears off easily due to the keyboard being farther back than usual .
# aspect :  paint
# polarity :  -1
# text_left :  the paint wears off easily due to the
# text_right :  being farther back than usual .
# aspect :  keyboard
# polarity :  -1
# text_left :  i had purchased it from a major electronics store and took it to their
# text_right :  to find out what the problem was .
# aspect :  service department
# polarity :  0
# text_left :  the store honored their
# text_right :  and made the comment that they do n't even recommend the hp brand because of the problems with their warrentys .
# aspect :  warrenty
# polarity :  1
# text_left :  the store honored their warrenty and made the comment that they do n't even recommend the hp brand because of the problems with their
# text_right :  .
# aspect :  warrentys
# polarity :  -1
# text_left :  i always use a backup
# text_right :  to store important files at all times .
# aspect :  hard disk
# polarity :  0
# text_left :  they sent out the box right away for me to send in my computer , they paid postage and whatnot , but when i got my computer back it still was n't running right , and now my
# text_right :  was n't reading anything !
# aspect :  cd drive
# polarity :  -1
# ...
# aspect :  wireless mouse
# polarity :  0
# text_left :  i had to buy a wireless mouse to go with it , as i am old school and hate the
# text_right :  , but knew that before i bought it , now it works great , need to get adjusted to the key board , as i am used to a bigger one and pounding .
# aspect :  pad
# polarity :  -1
# text_left :  i had to buy a wireless mouse to go with it , as i am old school and hate the pad , but knew that before i bought it , now it
# text_right :  great , need to get adjusted to the key board , as i am used to a bigger one and pounding .
# aspect :  works
# polarity :  1
# text_left :  i had to buy a wireless mouse to go with it , as i am old school and hate the pad , but knew that before i bought it , now it works great , need to get adjusted to the
# text_right :  , as i am used to a bigger one and pounding .
# aspect :  key board
# polarity :  0
# text_left :  when considering a mac , look at the total
# text_right :  and not just the initial price tag .
# aspect :  cost of ownership
# polarity :  0
# text_left :  when considering a mac , look at the total cost of ownership and not just the initial
# text_right :  .
# aspect :  price tag
# polarity :  0
# text_left :  has all the other
# text_right :  i wanted including a vga port , hdmi , ethernet and 3 usb ports .
# aspect :  features
# polarity :  1
# text_left :  has all the other features i wanted including a
# text_right :  , hdmi , ethernet and 3 usb ports .
# aspect :  vga port
# polarity :  0
# text_left :  has all the other features i wanted including a vga port ,
# text_right :  , ethernet and 3 usb ports .
# aspect :  hdmi
# polarity :  0
# text_left :  has all the other features i wanted including a vga port , hdmi ,
# text_right :  and 3 usb ports .
# aspect :  ethernet
# polarity :  0
# text_left :  has all the other features i wanted including a vga port , hdmi , ethernet and 3
# text_right :  .
# aspect :  usb ports
# polarity :  0
# text_left :  the only thing i dislike about this laptop are the
# text_right :  found on the bottom of the computer for grip .
# aspect :  rubber pads
# polarity :  -1
# text_left :  it 's a decent computer for the
# text_right :  and hopefully it will last a long time .
# aspect :  price
# polarity :  0
# text_left :  the nicest part is the low
# text_right :  and ultra quiet operation .
# aspect :  heat output
# polarity :  1
# text_left :  the nicest part is the low heat output and ultra quiet
# text_right :  .
# aspect :  operation
# polarity :  1
# text_left :  i will
# text_right :  myself -lrb- because with this model you can you can do it -rrb- later on .
# aspect :  upgrade the ram
# polarity :  1
# text_left :  the
# text_right :  is 200 dollars down .
# aspect :  price
# polarity :  1
# text_left :  this mac mini does not have a
# text_right :  , and it would seem that its mac os 10.9 does not handle external microphones properly .
# aspect :  built-in mic
# polarity :  0
# text_left :  this mac mini does not have a built-in mic , and it would seem that its
# text_right :  does not handle external microphones properly .
# aspect :  mac os 10.9
# polarity :  -1
# text_left :  this mac mini does not have a built-in mic , and it would seem that its mac os 10.9 does not handle
# text_right :  properly .
# aspect :  external microphones
# polarity :  0
# text_left :  a lot of
# text_right :  and shortcuts on the mbp that i was never exposed to on a normal pc .
# aspect :  features
# polarity :  0
# text_left :  a lot of features and
# text_right :  on the mbp that i was never exposed to on a normal pc .
# aspect :  shortcuts
# polarity :  0
# text_left :  was n't sure if i was going to like it much less love it so i went to a local best buy and played around with the
# text_right :  on a mac pro and it was totally unique and different .
# aspect :  ios system
# polarity :  1
# text_left :  air has higher
# text_right :  but the fonts are small .
# aspect :  resolution
# polarity :  1
# text_left :  air has higher resolution but the
# text_right :  are small .
# aspect :  fonts
# polarity :  -1
# text_left :
# text_right :  with mac is so much easier , so many cool features .
# aspect :  working
# polarity :  1
# text_left :  working with mac is so much easier , so many cool
# text_right :  .
# aspect :  features
# polarity :  1
# text_left :  i like the
# text_right :  and adjustments .
# aspect :  brightness
# polarity :  1
# text_left :  i like the brightness and
# text_right :  .
# aspect :  adjustments
# polarity :  1
# text_left :  i only wish this mac had a
# text_right :  built in .
# aspect :  cd/dvd player
# polarity :  0
# text_left :  the only thing i miss is that my old alienware laptop had
# text_right :  .
# aspect :  backlit keys
# polarity :  -1
# text_left :  the only thing i miss are the
# text_right :  and other things that i grew accustomed to after so long .
# aspect :  "home/end" type keys
# polarity :  0
# text_left :  so happy with this purchase , i just wish it came with
# text_right :  .
# aspect :  microsoft word
# polarity :  0
# text_left :  it has enough
# text_right :  and speed to run my business with all the flexibility that comes with a laptop .
# aspect :  memory
# polarity :  1
# text_left :  it has enough memory and
# text_right :  to run my business with all the flexibility that comes with a laptop .
# aspect :  speed
# polarity :  1
# text_left :  it has enough memory and speed to run my business with all the
# text_right :  that comes with a laptop .
# aspect :  flexibility
# polarity :  1
# text_left :  the
# text_right :  , the simplicity , the design . . it is lightyears ahead of any pc i have ever owned .
# aspect :  speed
# polarity :  1
# text_left :  the speed , the
# text_right :  , the design . . it is lightyears ahead of any pc i have ever owned .
# aspect :  simplicity
# polarity :  1
# text_left :  the speed , the simplicity , the
# text_right :  . . it is lightyears ahead of any pc i have ever owned .
# aspect :  design
# polarity :  1
# text_left :  the
# text_right :  is excellent , the display is excellent , and downloading apps is a breeze .
# aspect :  battery life
# polarity :  1
# text_left :  the battery life is excellent , the
# text_right :  is excellent , and downloading apps is a breeze .
# aspect :  display
# polarity :  1
# text_left :  the battery life is excellent , the display is excellent , and
# text_right :  is a breeze .
# aspect :  downloading apps
# polarity :  1
# text_left :  the
# text_right :  , the software and the smoothness of the operating system .
# aspect :  screen
# polarity :  1
# text_left :  the screen , the
# text_right :  and the smoothness of the operating system .
# aspect :  software
# polarity :  1
# text_left :  the screen , the software and the smoothness of the
# text_right :  .
# aspect :  operating system
# polarity :  1
# text_left :  i have dropped mine a couple times with only a
# text_right :  covering it .
# aspect :  slim plastic case
# polarity :  0
# text_left :  i also made a
# text_right :  .
# aspect :  recovery usb stick
# polarity :  0
# text_left :  but with this laptop , the
# text_right :  is very weak and the sound comes out sounding tinny .
# aspect :  bass
# polarity :  -1
# text_left :  but with this laptop , the bass is very weak and the
# text_right :  comes out sounding tinny .
# aspect :  sound
# polarity :  -1
# text_left :  the
# text_right :  is really good , i was so happy and excited about this product .
# aspect :  built quality
# polarity :  1
# text_left :  i am loving the fast
# text_right :  also .
# aspect :  performance
# polarity :  1
# text_left :  further , this mac mini has a sloppy
# text_right :  -lrb- courtesy of the mac os -rrb- and the range is poor .
# aspect :  bluetooth interface
# polarity :  -1
# text_left :  further , this mac mini has a sloppy bluetooth interface -lrb- courtesy of the
# text_right :  -rrb- and the range is poor .
# aspect :  mac os
# polarity :  -1
# text_left :  further , this mac mini has a sloppy bluetooth interface -lrb- courtesy of the mac os -rrb- and the
# text_right :  is poor .
# aspect :  range
# polarity :  -1
# text_left :  if you start on the far right side and scroll to your left the
# text_right :  will automatically come up .
# aspect :  start menu
# polarity :  0
# text_left :  my only gripe would be the need to add more
# text_right :  .
# aspect :  ram
# polarity :  -1
# text_left :  fine if you have a
# text_right :  .
# aspect :  touch screen
# polarity :  0
# text_left :  as far as user type - i dabble in everything from
# text_right :  -lrb- wow -rrb- to photoshop , but nothing professionally .
# aspect :  games
# polarity :  0
# text_left :  as far as user type - i dabble in everything from games -lrb- wow -rrb- to
# text_right :  , but nothing professionally .
# aspect :  photoshop
# polarity :  0
# text_left :  i re-seated the
# text_right :  inside and re-installed the lan device drivers .
# aspect :  "wlan" card
# polarity :  0
# text_left :  i re-seated the `` wlan '' card inside and re-installed the
# text_right :  .
# aspect :  lan device drivers
# polarity :  0
# text_left :  this by far beats any computer out on the market today
# text_right :  well , battery life amazing .
# aspect :  built
# polarity :  1
# text_left :  this by far beats any computer out on the market today built well ,
# text_right :  amazing .
# aspect :  battery life
# polarity :  1
# text_left :  the
# text_right :  is easy , and offers all kinds of surprises .
# aspect :  os
# polarity :  1
# text_left :  i had to get
# text_right :  to correct the problem .
# aspect :  apple customer support
# polarity :  0
# text_left :  a veryimportant feature is
# text_right :  which in my experience works better then usb3 -lrb- in pc enabled with usb3 -rrb- i was not originally sold on the mac os i felt it was inferior in many ways to windows 7 .
# aspect :  firewire 800
# polarity :  1
# text_left :  a veryimportant feature is firewire 800 which in my experience works better then
# text_right :  -lrb- in pc enabled with usb3 -rrb- i was not originally sold on the mac os i felt it was inferior in many ways to windows 7 .
# aspect :  usb3
# polarity :  -1
# text_left :  a veryimportant feature is firewire 800 which in my experience works better then usb3 -lrb- in pc enabled with
# text_right :  -rrb- i was not originally sold on the mac os i felt it was inferior in many ways to windows 7 .
# aspect :  usb3
# polarity :  0
# text_left :  a veryimportant feature is firewire 800 which in my experience works better then usb3 -lrb- in pc enabled with usb3 -rrb- i was not originally sold on the
# text_right :  i felt it was inferior in many ways to windows 7 .
# aspect :  mac os
# polarity :  -1
# text_left :  a veryimportant feature is firewire 800 which in my experience works better then usb3 -lrb- in pc enabled with usb3 -rrb- i was not originally sold on the mac os i felt it was inferior in many ways to
# text_right :  .
# aspect :  windows 7
# polarity :  1
# text_left :  i like
# text_right :  , the apparent security , the mini form factor , all the nice graphics stuff .
# aspect :  itunes
# polarity :  1
# text_left :  i like itunes , the apparent
# text_right :  , the mini form factor , all the nice graphics stuff .
# aspect :  security
# polarity :  1
# text_left :  i like itunes , the apparent security , the
# text_right :  , all the nice graphics stuff .
# aspect :  mini form factor
# polarity :  1
# text_left :  i like itunes , the apparent security , the mini form factor , all the nice
# text_right :  .
# aspect :  graphics stuff
# polarity :  1
# text_left :  the first time i used the
# text_right :  it took half an hour and a pair of tweezers to remove the card .
# aspect :  card reader
# polarity :  -1
# text_left :  the first time i used the card reader it took half an hour and a pair of tweezers to
# text_right :  .
# aspect :  remove the card
# polarity :  -1
# text_left :  after replacing the
# text_right :  with an ssd drive , my mac is just flying .
# aspect :  spinning hard disk
# polarity :  0
# text_left :  after replacing the spinning hard disk with an
# text_right :  , my mac is just flying .
# aspect :  ssd drive
# polarity :  1
# text_left :  i know some people complained about
# text_right :  issues but they released a firmware patch to address that issue .
# aspect :  hdmi
# polarity :  0
# text_left :  i know some people complained about hdmi issues but they released a
# text_right :  to address that issue .
# aspect :  firmware patch
# polarity :  0
# text_left :  with the needs of a professional photographer i generally need to keep up with the best
# text_right :  .
# aspect :  specs
# polarity :  0
# text_left :
# text_right :  and everything was perfect
# aspect :  packing
# polarity :  1
# text_left :  i called toshiba where i gave them the serial number and they informed me that they were having issues with the
# text_right :  .
# aspect :  mother boards
# polarity :  0
# text_left :  i seem to be having repeat problems as the
# text_right :  in this one is diagnosed as faulty , related to the graphics card .
# aspect :  mother board
# polarity :  -1
# text_left :  i seem to be having repeat problems as the mother board in this one is diagnosed as faulty , related to the
# text_right :  .
# aspect :  graphics card
# polarity :  -1
# text_left :  it also comes with
# text_right :  but if you 're like me you want to max that out so i immediately put 8g of ram in her and i 've never used a computer that performs better .
# aspect :  4g of ram
# polarity :  0
# text_left :  it also comes with 4g of ram but if you 're like me you want to max that out so i immediately put
# text_right :  in her and i 've never used a computer that performs better .
# aspect :  8g of ram
# polarity :  0
# text_left :  it also comes with 4g of ram but if you 're like me you want to max that out so i immediately put 8g of ram in her and i 've never used a computer that
# text_right :  better .
# aspect :  performs
# polarity :  1
# text_left :  this computer is also awesome for my sons
# text_right :  .
# aspect :  virtual home schooling
# polarity :  1
# text_left :
# text_right :  is more as compared to other brands .
# aspect :  cost
# polarity :  -1
# text_left :  also ... - excellent
# text_right :  - size and weight for optimal mobility - excellent durability of the battery - the functions provided by the trackpad is unmatched by any other brand -
# aspect :  operating system
# polarity :  1
# text_left :  also ... - excellent operating system -
# text_right :  and weight for optimal mobility - excellent durability of the battery - the functions provided by the trackpad is unmatched by any other brand -
# aspect :  size
# polarity :  1
# text_left :  also ... - excellent operating system - size and
# text_right :  for optimal mobility - excellent durability of the battery - the functions provided by the trackpad is unmatched by any other brand -
# aspect :  weight
# polarity :  1
# text_left :  also ... - excellent operating system - size and weight for optimal
# text_right :  - excellent durability of the battery - the functions provided by the trackpad is unmatched by any other brand -
# aspect :  mobility
# polarity :  1
# text_left :  also ... - excellent operating system - size and weight for optimal mobility - excellent
# text_right :  - the functions provided by the trackpad is unmatched by any other brand -
# aspect :  durability of the battery
# polarity :  1
# text_left :  also ... - excellent operating system - size and weight for optimal mobility - excellent durability of the battery - the
# text_right :  is unmatched by any other brand -
# aspect :  functions provided by the trackpad
# polarity :  1
# text_left :  this
# text_right :  seems to be better than the imac in that it is n't $ 1400 and smaller .
# aspect :  hardware
# polarity :  1
# text_left :  i 've had it for about 2 months now and found no issues with
# text_right :  or updates .
# aspect :  software
# polarity :  0
# text_left :  i 've had it for about 2 months now and found no issues with software or
# text_right :  .
# aspect :  updates
# polarity :  0
# text_left :  the latest version does not have a
# text_right :  .
# aspect :  disc drive
# polarity :  0
# text_left :
# text_right :  - although some people might complain about low res which i think is ridiculous .
# aspect :  screen
# polarity :  1
# text_left :  screen - although some people might complain about low
# text_right :  which i think is ridiculous .
# aspect :  res
# polarity :  1
# number of traning data 2328
# number of testing data 638

# %% [markdown]
# # Convert data into DataFrame

# %%
import pandas as pd
"""
'[SEP]': A token used in BERT model to represent seperating two sentences.
'[CLS]': token (short for “classification”) to the start of each sentence (this is essentially like a start-of-sentence token)
"""
train_df = trainset.get_dataframe(tokenizer)
test_df = testset.get_dataframe(tokenizer)

# %%
train_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                          text_bert_indices  \
# 0    [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] cord [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] battery life [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                        [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] service center [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                                            [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the " sales " team , which is the retail shop which i bought my net ##book from . [SEP] " sales " team [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                              [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] tech guy [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      bert_segments_ids  \
# 0              [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1          [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2          [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4          [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                     text_raw_bert_indices  \
# 0  [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                          [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                                  [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the " sales " team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                          [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   aspect_bert_indices  \
# 0      [CLS] cord [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1    [CLS] battery life [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  [CLS] service center [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3              [CLS] " sales " team [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4        [CLS] tech guy [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                          text_raw_indices  \
# 0  i charge it at night and skip taking the cord with me because of the good battery life . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  i charge it at night and skip taking the cord with me because of the good battery life . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                          the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                                  the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the " sales " team , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                          the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                            text_raw_without_aspect_indices  \
# 0  i charge it at night and skip taking the with me because of the good battery life . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1    i charge it at night and skip taking the cord with me because of the good . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                              the tech guy then said the does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                          the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                        the then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                text_left_indices  \
# 0             i charge it at night and skip taking the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                      i charge it at night and skip taking the cord with me because of the good [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2         the tech guy then said the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                           the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4  the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 text_left_with_aspect_indices  \
# 0           i charge it at night and skip taking the cord [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                  i charge it at night and skip taking the cord with me because of the good battery life [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2   the tech guy then said the service center [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                                 the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the " sales " team [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4  the tech guy [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text_right_indices  \
# 0         . life battery good the of because me with [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                                         . from ##book net my bought i which shop retail the is which , team ' ' sales ` ` the to concern my direct to have i and exchange 1 - to - 1 do not does [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                   . from ##book net my bought i which shop retail the is which , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                                          . from ##book net my bought i which shop retail the is which , team ' ' sales ` ` the to concern my direct to have i and exchange 1 - to - 1 do not does center service the said then [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  text_right_with_aspect_indices  \
# 0           . life battery good the of because me with cord [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  . life battery [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                                       . from ##book net my bought i which shop retail the is which , team ' ' sales ` ` the to concern my direct to have i and exchange 1 - to - 1 do not does center service [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                             . from ##book net my bought i which shop retail the is which , team " sales " [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                                              . from ##book net my bought i which shop retail the is which , team ' ' sales ` ` the to concern my direct to have i and exchange 1 - to - 1 do not does center service the said then guy tech [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        aspect_indices  \
# 0      cord [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1    battery life [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  service center [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3              " sales " team [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4        tech guy [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#   aspect_in_text  polarity
# 0         [9, 9]         1
# 1       [16, 17]         2
# 2         [6, 7]         0
# 3       [26, 29]         0
# 4         [1, 2]         1

# %%
# label distribution
from pylab import rcParams
rcParams['figure.figsize'] = 8, 4

# train
train_df.polarity \
.apply(lambda x: {2:'positive',1:'neutral',0:'negative'}[x])\
.value_counts().plot(kind = 'bar', fontsize = 15)

# %%
# test
test_df.polarity \
.apply(lambda x: {2:'positive',1:'neutral',0:'negative'}[x])\
.value_counts().plot(kind = 'bar', fontsize = 15)

# %% [markdown]
# # model input

# %%
# model's input for inference
input_colses = {
    'lstm': ['text_raw_indices'],
    'td_lstm': ['text_left_with_aspect_indices', 'text_right_with_aspect_indices'],
    'atae_lstm': ['text_raw_indices', 'aspect_indices'],
    'ian': ['text_raw_indices', 'aspect_indices'],
    'memnet': ['text_raw_without_aspect_indices', 'aspect_indices'],
    'ram': ['text_raw_indices', 'aspect_indices', 'text_left_indices'],
    'cabasc': ['text_raw_indices', 'aspect_indices', 'text_left_with_aspect_indices', 'text_right_with_aspect_indices'],
    'tnet_lf': ['text_raw_indices', 'aspect_indices', 'aspect_in_text'],
    'aoa': ['text_raw_indices', 'aspect_indices'],
    'mgan': ['text_raw_indices', 'aspect_indices', 'text_left_indices'],
    'bert_spc': ['text_bert_indices', 'bert_segments_ids'], # Sentence Pair Classification
    'aen_bert': ['text_raw_bert_indices', 'aspect_bert_indices'],
}
train_df[input_colses['aen_bert']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text_raw_bert_indices  \
# 0                          [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                          [CLS] i charge it at night and skip taking the cord with me because of the good battery life . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                                                                                  [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                                                                          [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the " sales " team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                                                                  [CLS] the tech guy then said the service center does not do 1 - to - 1 exchange and i have to direct my concern to the ` ` sales ' ' team , which is the retail shop which i bought my net ##book from . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 2323           [CLS] we also use para ##lles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2324           [CLS] we also use para ##lles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2325           [CLS] we also use para ##lles so we can run virtual machines of windows xp professional , windows 7 home premium , windows server enterprise 2003 , and windows server 2008 enterprise . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2326                                   [CLS] how to ##shi ##ba handles the repair seems to vary , some folks indicate that they were charged for even an int ##ial fix , others had the repair done 5 times . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2327  [CLS] i would like to use a different operating system altogether . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          aspect_bert_indices
# 0             [CLS] cord [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1           [CLS] battery life [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2         [CLS] service center [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                     [CLS] " sales " team [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4               [CLS] tech guy [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 2323          [CLS] windows 7 home premium [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2324  [CLS] windows server enterprise 2003 [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2325  [CLS] windows server 2008 enterprise [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2326        [CLS] repair [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2327    [CLS] operating system [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
# [2328 rows x 2 columns]

# %% [markdown]
# # aspect analysis
# ### 1. num_aspect_words
# ### 2. aspect words in text

# %%
train_df.num_aspect_words = train_df.aspect_in_text.apply(lambda x: x[1]-x[0]+1)
test_df.num_aspect_words = test_df.aspect_in_text.apply(lambda x: x[1]-x[0]+1)

train_df.num_aspect_words.value_counts().plot(kind = 'bar', fontsize = 15)
# Out:
# /ldap_home/yunrui.li/.pyenv/versions/3.6.5/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /ldap_home/yunrui.li/.pyenv/versions/3.6.5/envs/test/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# aspect words in text
# def aspect_words(row):
#     print (type(row), list(row))
#     aspect_tokens = row.aspect_indices.apply(lambda x: x.split(" "))
#     print (aspect_tokens)
#     aspect_indexs = row.num_aspect_words
#     row.aspect_in_text = aspect_tokens[:aspect_indexs]
aspect_tokens = train_df.aspect_indices.apply(lambda x: x.split(" ")).tolist()
aspect_in_text = [" ".join(t_ls[:n_words]) for t_ls,n_words in zip(aspect_tokens, train_df.num_aspect_words)]
train_df["aspect_in_text_str"] = aspect_in_text
train_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  text_bert_indices  \
# 0  [CLS] but the staff was so horrible to us . [SEP] staff [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                         [CLS] to be completely fair , the only red ##eem ##ing factor was the food , which was above average , but could n ' t make up for all the other def ##iciencies of te ##od ##ora . [SEP] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                    [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                 [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] kitchen [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                    [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] menu [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          bert_segments_ids  \
# 0  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                              text_raw_bert_indices  \
# 0  [CLS] but the staff was so horrible to us . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                        [CLS] to be completely fair , the only red ##eem ##ing factor was the food , which was above average , but could n ' t make up for all the other def ##iciencies of te ##od ##ora . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                   [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                   [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                   [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  aspect_bert_indices  \
# 0    [CLS] staff [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1     [CLS] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2     [CLS] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  [CLS] kitchen [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4     [CLS] menu [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text_raw_indices  \
# 0  but the staff was so horrible to us . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                        to be completely fair , the only red ##eem ##ing factor was the food , which was above average , but could n ' t make up for all the other def ##iciencies of te ##od ##ora . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                   the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                   the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                   the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                    text_raw_without_aspect_indices  \
# 0  but the was so horrible to us . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                       to be completely fair , the only red ##eem ##ing factor was the , which was above average , but could n ' t make up for all the other def ##iciencies of te ##od ##ora . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                  the is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                     the food is uniformly exceptional , with a very capable which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                  the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the or not . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                text_left_indices  \
# 0    but the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1              to be completely fair , the only red ##eem ##ing factor was the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3    the food is uniformly exceptional , with a very capable [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                       the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                    text_left_with_aspect_indices  \
# 0    but the staff [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1               to be completely fair , the only red ##eem ##ing factor was the food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2   the food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  the food is uniformly exceptional , with a very capable kitchen [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                        the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        text_right_indices  \
# 0     . us to horrible so was [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                . ##ora ##od te of ##iciencies def other the all for up make t ' n could but , average above was which , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                       . not or menu the on s ' it whether , eating like feel you whatever up whip proudly will which kitchen capable very a with , exceptional uniformly is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                        . not or menu the on s ' it whether , eating like feel you whatever up whip proudly will which [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4  . not or [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                           text_right_with_aspect_indices  \
# 0    . us to horrible so was staff [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                . ##ora ##od te of ##iciencies def other the all for up make t ' n could but , average above was which , food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                       . not or menu the on s ' it whether , eating like feel you whatever up whip proudly will which kitchen capable very a with , exceptional uniformly is food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                     . not or menu the on s ' it whether , eating like feel you whatever up whip proudly will which kitchen [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4  . not or menu [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       aspect_indices  \
# 0    staff [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1     food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2     food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  kitchen [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4     menu [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#   aspect_in_text  polarity aspect_in_text_str
# 0         [2, 2]         0              staff
# 1       [13, 13]         2               food
# 2         [1, 1]         2               food
# 3       [10, 10]         2            kitchen
# 4       [28, 28]         1               menu

# %%
"staff" in "[CLS] but the staff was so horrible to us . [SEP] staff [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD"
# Out:
# True

# %%
train_df["if_aspect_in_text"] = [1 if aspect in text else 0 
 for text, aspect in zip(train_df.text_bert_indices,train_df.aspect_in_text_str)]

# %%
train_df.if_aspect_in_text.value_counts()
# Out:
# 1    3606
# 0       2
# Name: if_aspect_in_text, dtype: int64

# %%
train_df[train_df.if_aspect_in_text == 0]
# Out:
#                                                                                                                                                                                                                                                                                                                                                             text_bert_indices  \
# 2600  [CLS] i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b
# 2601  [CLS] i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     bert_segments_ids  \
# 2600  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2601  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                         text_raw_bert_indices  \
# 2600  [CLS] i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b
# 2601  [CLS] i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                aspect_bert_indices  \
# 2600  [CLS] main en ##tree [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2601    [CLS] cold ud ##on [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                          text_raw_indices  \
# 2600  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
# 2601  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
#
#                                                                                                                                                                                                                                                                                                                                           text_raw_without_aspect_indices  \
# 2600  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
# 2601  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
#
#                                                                                                                                                                                                                                                                                                                                                         text_left_indices  \
# 2600  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
# 2601  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
#
#                                                                                                                                                                                                                                                                                                                                             text_left_with_aspect_indices  \
# 2600  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
# 2601  i must warn the reader that the portions sizes are very small - l ##rb - especially the app ##eti ##zers - rr ##b - , so if you plan to eat until you are full and do not intend to order the chef ' s special tasting menu , prepare to order and pay for an app ##eti ##zer - l ##rb - 1 dish for each person because the portions are not for sharing - rr ##b -
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                   text_right_indices  \
# 2600               . meal the of end the at ##on ud cold the and , [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2601  . meal the of end the at [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  text_right_with_aspect_indices  \
# 2600             . meal the of end the at ##on ud cold the and , ##tree en main [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2601  . meal the of end the at ##on ud cold [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     aspect_indices  \
# 2600  main en ##tree [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2601    cold ud ##on [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#      aspect_in_text  polarity aspect_in_text_str  if_aspect_in_text
# 2600       [80, 82]         1     main en ##tree                  0
# 2601       [80, 82]         1       cold ud ##on                  0

# %%
train_df["aspect_in_text_str"].nunique()
# Out:
# 1202

# %%
train_aspect_word = set(train_df["aspect_in_text_str"].unique())

# %%
aspect_tokens = test_df.aspect_indices.apply(lambda x: x.split(" ")).tolist()
aspect_in_text = [" ".join(t_ls[:n_words]) for t_ls,n_words in zip(aspect_tokens, test_df.num_aspect_words)]
test_df["aspect_in_text_str"] = aspect_in_text
test_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text_bert_indices  \
# 0           [CLS] the bread is top notch as well . [SEP] bread [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                 [CLS] i have to say they have one of the fastest delivery times in the city . [SEP] delivery times [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                 [CLS] food is always fresh and hot - ready to eat ! [SEP] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  [CLS] did i mention that the coffee is outstanding ? [SEP] coffee [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                   [CLS] certainly not the best su ##shi in new york , however , it is always fresh , and the place is very clean , sterile . [SEP] place [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              bert_segments_ids  \
# 0      [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2      [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3      [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4      [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                       text_raw_bert_indices  \
# 0          [CLS] the bread is top notch as well . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                   [CLS] i have to say they have one of the fastest delivery times in the city . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2               [CLS] food is always fresh and hot - ready to eat ! [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  [CLS] did i mention that the coffee is outstanding ? [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                  [CLS] certainly not the best su ##shi in new york , however , it is always fresh , and the place is very clean , sterile . [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   aspect_bert_indices  \
# 0     [CLS] bread [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  [CLS] delivery times [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2      [CLS] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3    [CLS] coffee [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4     [CLS] place [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text_raw_indices  \
# 0          the bread is top notch as well . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                   i have to say they have one of the fastest delivery times in the city . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2               food is always fresh and hot - ready to eat ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  did i mention that the coffee is outstanding ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                  certainly not the best su ##shi in new york , however , it is always fresh , and the place is very clean , sterile . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            text_raw_without_aspect_indices  \
# 0         the is top notch as well . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                     i have to say they have one of the fastest in the city . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2             is always fresh and hot - ready to eat ! [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  did i mention that the is outstanding ? [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                                 certainly not the best su ##shi in new york , however , it is always fresh , and the is very clean , sterile . [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  text_left_indices  \
# 0    the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                   i have to say they have one of the fastest [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3         did i mention that the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                               certainly not the best su ##shi in new york , however , it is always fresh , and the [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text_left_with_aspect_indices  \
# 0   the bread [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1               i have to say they have one of the fastest delivery times [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2  food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3       did i mention that the coffee [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                              certainly not the best su ##shi in new york , however , it is always fresh , and the place [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                text_right_indices  \
# 0              . well as notch top is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1           . city the in [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                    ! eat to ready - hot and fresh always is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  ? outstanding is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4           . sterile , clean very is [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text_right_with_aspect_indices  \
# 0               . well as notch top is bread [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1         . city the in times delivery [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                      ! eat to ready - hot and fresh always is food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3  ? outstanding is coffee [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4            . sterile , clean very is place [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        aspect_indices  \
# 0     bread [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1  delivery times [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2      food [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3    coffee [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4     place [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#   aspect_in_text  polarity aspect_in_text_str
# 0         [1, 1]         2              bread
# 1       [10, 11]         2     delivery times
# 2         [0, 0]         2               food
# 3         [5, 5]         2             coffee
# 4       [19, 19]         2              place

# %%
test_df["aspect_in_text_str"].nunique()
# Out:
# 520

# %%
test_aspect_word = set(test_df["aspect_in_text_str"].unique())

# %%
test_aspect_word - train_aspect_word
# Out:
# {'" roy \' s classics "',
#  '[ female ] servers',
#  'afternoon snack',
#  "ama ##zin ' greens salad ##s",
#  'an ##cho ##vy dressing',
#  'app ##eti ##zer selection',
#  'apple tar ##t',
#  'argentine cho ##riz ##o app ##eti ##zer',
#  'array of su ##shi',
#  'art ##ific ##al lobster meat',
#  'as ##para ##gus',
#  'asian fusion',
#  'asian salad',
#  'assortment of wraps',
#  'av ##oca ##do salad',
#  'banana pudding',
#  'bar menu',
#  'bb ##q rib',
#  'beans',
#  'beer list',
#  'bi - level space',
#  'big mac',
#  'billed',
#  'bis ##tro menu',
#  'black cod with mis ##o base',
#  'black roasted cod ##fish',
#  'black vinegar',
#  'blue ##berry pancakes',
#  'blue bar area',
#  'booth by the windows',
#  'boutique selection of wines',
#  'br ##un ##ch menu',
#  'bra ##ised lamb shan ##k with mas ##hed potatoes',
#  'bran ##zin ##i',
#  'breakfast',
#  'breakfast food',
#  'breakfast sandwiches',
#  'brisk ##et',
#  'buffalo chicken kicker ##s',
#  'burr ##ito',
#  'ca ##ese ##r salad',
#  'ca ##jun shrimp',
#  'ca ##via ##r - topped stu ##rgeon',
#  'cake',
#  "calf ' s liver",
#  'candle ##light',
#  'car ##int ##hia cheese ravi ##oli with wild mushrooms',
#  'carrot ##s',
#  'casual drink',
#  'casual lunch ##es',
#  'catfish',
#  'chairs',
#  'cheese ba ##cl ##ava',
#  'cherry mars ##cap ##one',
#  'chick ##pe ##as',
#  'chick peas with shrimp ( app ##eti ##zer )',
#  'chicken and fa ##la ##fe ##l platt ##ers',
#  'chicken dinner',
#  'chicken mc ##nu ##gg ##ets',
#  'chicken milan ##ese',
#  'chicken par ##mi ##gia ##na',
#  'chicken ta ##cos',
#  'chicken ter ##iya ##ki',
#  'chicken with av ##oca ##do',
#  'chili signed food items',
#  'chocolate and peanut butter tar ##t',
#  'chocolate frost ##y',
#  'chocolate ras ##p ##berry cake',
#  'choices of sauce ##s',
#  'chu ##rra ##sco',
#  'ci ##nna st ##ix',
#  'client ##ele',
#  'co ##si sandwiches',
#  'cocktail hour',
#  'cocktail menu',
#  'cold sesame noodles',
#  'cooked food',
#  'cookie',
#  'cr ##ep ##es',
#  'crab ##cake ##s',
#  'creamy app ##eti ##zers',
#  'currie ##d cass ##ero ##les',
#  'da ##bs of real mo ##zza ##rella',
#  'deco',
#  'decoration',
#  'del ##ivar ##y',
#  'del ##mon ##ico steak',
#  'delivers',
#  'delivery times',
#  'deserts',
#  'dessert pizza',
#  'din ##e - in',
#  'dining atmosphere',
#  'disco pop duo',
#  'display and quality of the food',
#  'downstairs bar scene',
#  'duck',
#  'duck con ##fi ##tte',
#  'egg',
#  'egg ##pl ##ant salad',
#  'egg mc ##mu ##ffin sandwich',
#  'em ##pen ##ada ##s',
#  'en ##tree - sized salad ##s',
#  'english mu ##ffin ##s',
#  'er ##ba ##zzo ##ne emilia ##na',
#  'f ##oca ##cchi ##a bread',
#  'f ##oi ##e gr ##as',
#  'f ##oi ##e gr ##as una ##gi nap ##ole ##an',
#  'fa ##jit ##a',
#  'fa ##la ##fa ##l',
#  'fa ##la ##fe ##l',
#  'fe ##tt ##uc ##ino alfredo',
#  'fe ##tt ##ucci ##ne alfredo',
#  'fe ##tt ##ucci ##ne with grille ##d seafood in a rosemary - orange sauce',
#  'fen ##nel flavor ##ed italian sausage',
#  'file ##t - o - fish sandwich',
#  'fl ##an',
#  'folding chair',
#  'foo ##ood',
#  'food portion',
#  'fork',
#  'fortune cookies',
#  'french dish',
#  'french fries - - with the ka ##lma ##ta dip',
#  'fresh juice ##s',
#  'fresh juice con ##co ##ctions',
#  'fresh leaf salad',
#  'fresh salsa',
#  'fresh ve ##gg ##ies',
#  'fried cal ##ama ##ri',
#  'fried foods',
#  'fried pan ##cake served with pun ##gent curry dipping sauce',
#  'fried pork dump ##lings',
#  'garlic soup',
#  'gr ##at ##uity',
#  'grand mar ##nier shrimp',
#  'greek food',
#  'greek yo ##gur ##t ( with cu ##cc ##umber , dil ##l , and garlic )',
#  'green beans',
#  'green chill ##is',
#  'green spin ##ach - vodka sauce',
#  'grill',
#  'grille ##d cheese ##s',
#  'ground chick ##pe ##a soup',
#  'hal ##ib ##ut cheek app ##eti ##zer',
#  'hamburger',
#  'happy hour',
#  'hi ##bis ##cus lemon ##ade',
#  'hint of cocoa',
#  'homemade bread ##s',
#  'homemade gu ##aca ##mo ##le',
#  'homemade pasta ##s',
#  'homemade so ##rb ##ets',
#  'honey bb ##q rib tips',
#  'hong kong - style food',
#  'host ( owner )',
#  'hot ##dog ##s',
#  'hot and sour soup',
#  'hot cakes',
#  'hot dog',
#  'hot white mo ##cha',
#  'hum ##us',
#  'ice drink',
#  'iced blended mo ##cha',
#  'italian cuisine',
#  'italian meal',
#  'ja ##p style hamburger steak',
#  'japanese dishes',
#  'jazz singer',
#  'jerusalem market - style fa ##la ##fe ##l wraps',
#  'kim ##ono shrimp special',
#  'king crab salad with passion fruit vin ##ai ##gre ##tte',
#  'kitchen food',
#  'ko ##mp ##ot',
#  'korean dishes',
#  'l ##ych ##ee martini',
#  'lamb en ##tree',
#  'lamb ke ##ba ##bs',
#  'las ##ag ##na',
#  'late lunch',
#  'latin food',
#  'lemon - dressed cobb',
#  'lighting',
#  'lobster ri ##so ##tto',
#  'long bar',
#  'lounge',
#  'mac ##ada ##mia - crust ##ed ma ##hi ma ##hi',
#  'mac and cheese',
#  'mac cheese',
#  'mal ##ted milk ball gel ##ato',
#  'mango margaret ##a',
#  "mcdonald ' s famous french fries",
#  'meat ##ball par ##m',
#  'meat ##y chili',
#  'mediterranean delight ##s',
#  'mediterranean salad ##s - - layered with bee ##ts , goat cheese and walnut ##s',
#  'menu ##s',
#  'middle eastern spreads',
#  'milk ##sha ##kes',
#  'mo ##jit ##o',
#  'mo ##jit ##os',
#  'mo ##zza ##rella sticks',
#  'mole sauce',
#  'most ##ard ##a on the cheese plate',
#  'mushroom barley soup',
#  'new hamburger with special sauce',
#  'new menu',
#  'nico ##ise olive ##s',
#  'nico ##ise salad',
#  'non - meat alternatives',
#  'non - su ##shi selection',
#  'odessa stew',
#  'onion rings',
#  'orange chicken / beef',
#  'orange don ##ut',
#  'organic grille ##d burger ##s',
#  'outdoor eating area',
#  'outdoors',
#  'par ##mes ##an cheese',
#  'para ##tha',
#  'parking',
#  'pasta prima ##vera',
#  'pasta specials',
#  'patti ##es',
#  'peanut butter so ##rb ##et',
#  'pia ##lla',
#  "pizza ' s",
#  'pizza with soy cheese',
#  'plain ##tain ##s',
#  'poor ##i',
#  'pork product',
#  'port',
#  'port ##abe ##lla las ##ag ##na',
#  'portion of f ##oi ##e gr ##as',
#  'portions of the food',
#  'porto ##bell ##o / go ##rgo ##nzo ##la / sausage app ##eti ##zer',
#  'portuguese cheese cart',
#  'potato gr ##atin',
#  'potato spin ##ach g ##no ##cchi',
#  'pre - show meal',
#  'pub fare',
#  'qu ##ail ##ity',
#  'quality of the meat',
#  'que ##sed ##illa',
#  'rabbit',
#  'rabbit stew',
#  'rack of lamb in black tr ##uf ##fle sauce',
#  'recipes',
#  'red onion',
#  'rep ##ast',
#  'ribs',
#  'rice medley',
#  'rice milk',
#  'roasted chickens',
#  'rolls with crab',
#  'rooftop bar',
#  'rose roll',
#  'rot ##i can ##ai app ##eti ##zer',
#  'round corner table next to the large window',
#  'sa ##ag go ##sh ##t',
#  'sake ##tin ##i',
#  'salad ##s ( av ##oca ##do shrimp )',
#  'salad dressing',
#  'sales people',
#  'salmon dishes',
#  'sash ##imi portion',
#  'sauce cart',
#  'seafood pa ##ella for two',
#  'selection of food',
#  'selection of wines ( primarily spanish )',
#  'shepherd ##s pie',
#  'shredded ginger',
#  'shrimp creole',
#  'shrimp dish ##s',
#  'side orders',
#  'size',
#  'sliced steak en ##tree',
#  'slices',
#  'smoked trout',
#  'smooth ##ies',
#  'so ##pa ##ip ##illa ##s',
#  'soft shell crab',
#  'soft shell crab sandwich with fries',
#  'soul food',
#  'soup and sandwich meal',
#  'soy mayo ##nais ##e',
#  'spicy cod roe spaghetti',
#  'spicy mu ##ssel ##s',
#  'spin ##ach thing',
#  'staff me ##me ##bers',
#  'staff members',
#  'staff person',
#  'stuffed baked potatoes',
#  'su ##shi / sash ##imi',
#  'su ##shi lunch',
#  'sweet corn - f ##oi ##e gr ##as br ##ule ##e',
#  'sweet honey - mustard beef short ribs',
#  'sweets',
#  'ta ##cos',
#  'ta ##cos pastor',
#  'ta ##tor to ##ts',
#  'tab ##ou ##le ##h',
#  'tag ##lier ##ini with tr ##uf ##fles',
#  'take - out',
#  'tar ##t of the day',
#  'tara ##mas ##ala ##ta',
#  'taylor ham',
#  'tea ##s',
#  'tequila',
#  'ter ##iya ##ki',
#  'texture',
#  'thin crust',
#  'to ##stad ##a de ting ##a',
#  'traditional italian items',
#  'traditional mediterranean fare',
#  'treats',
#  'twist on pizza',
#  'ups ##tra ##irs dining area',
#  'ut ##ens ##ils',
#  've ##al chop ##s',
#  've ##gg ##ie burger',
#  'vega ##n cr ##an ##berry pancakes',
#  'vega ##n options',
#  'vegetable ri ##so ##tto',
#  'vegetarian platt ##ers',
#  'vietnamese beef no ##odle soup',
#  'vintage ##s',
#  "waitress ' s",
#  'warm pit ##as',
#  'wheat crust ##ed pizza',
#  'wings',
#  'wraps',
#  'yellow ##fin tuna'}

# %% [markdown]
# # model's input for inference
# ### bert_spc:

# %%
# model's input for inference
input_colses = {
    'lstm': ['text_raw_indices'],
    'td_lstm': ['text_left_with_aspect_indices', 'text_right_with_aspect_indices'],
    'atae_lstm': ['text_raw_indices', 'aspect_indices'],
    'ian': ['text_raw_indices', 'aspect_indices'],
    'memnet': ['text_raw_without_aspect_indices', 'aspect_indices'],
    'ram': ['text_raw_indices', 'aspect_indices', 'text_left_indices'],
    'cabasc': ['text_raw_indices', 'aspect_indices', 'text_left_with_aspect_indices', 'text_right_with_aspect_indices'],
    'tnet_lf': ['text_raw_indices', 'aspect_indices', 'aspect_in_text'],
    'aoa': ['text_raw_indices', 'aspect_indices'],
    'mgan': ['text_raw_indices', 'aspect_indices', 'text_left_indices'],
    'bert_spc': ['text_bert_indices', 'bert_segments_ids'],
    'aen_bert': ['text_raw_bert_indices', 'aspect_bert_indices'],
}
train_df[input_colses['bert_spc']+["aspect_in_text_str"]]
"""
現有Paper在inference需要決定text中的aspect啊. 去 check infer_example.py晚點
"""
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                     text_bert_indices  \
# 0     [CLS] but the staff was so horrible to us . [SEP] staff [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                                            [CLS] to be completely fair , the only red ##eem ##ing factor was the food , which was above average , but could n ' t make up for all the other def ##iciencies of te ##od ##ora . [SEP] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                       [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] food [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                    [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] kitchen [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                       [CLS] the food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it ' s on the menu or not . [SEP] menu [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 3603                       [CLS] each table has a pot of boiling water sunken into its surface , and you get platt ##ers of thin sliced meat ##s , various vegetables , and rice and glass noodles . [SEP] pot of boiling water [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3604                       [CLS] each table has a pot of boiling water sunken into its surface , and you get platt ##ers of thin sliced meat ##s , various vegetables , and rice and glass noodles . [SEP] meat ##s [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3605               [CLS] each table has a pot of boiling water sunken into its surface , and you get platt ##ers of thin sliced meat ##s , various vegetables , and rice and glass noodles . [SEP] vegetables [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3606                     [CLS] each table has a pot of boiling water sunken into its surface , and you get platt ##ers of thin sliced meat ##s , various vegetables , and rice and glass noodles . [SEP] rice [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3607                  [CLS] each table has a pot of boiling water sunken into its surface , and you get platt ##ers of thin sliced meat ##s , various vegetables , and rice and glass noodles . [SEP] glass noodles [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         bert_segments_ids  \
# 0                 [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 1                 [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 2                 [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3                 [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 4                 [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 3603  [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3604          [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3605              [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3606              [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# 3607          [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [unused0] [unused0] [unused0] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
#
#         aspect_in_text_str
# 0                    staff
# 1                     food
# 2                     food
# 3                  kitchen
# 4                     menu
# ...                    ...
# 3603  pot of boiling water
# 3604              meat ##s
# 3605            vegetables
# 3606                  rice
# 3607         glass noodles
#
# [3608 rows x 3 columns]

# %%
train

# %%
# # to understanding each data's physcial meaning
# train_df = []
# columns_name = []
# for i in range(len(trainset)):
#     tmp = []
#     for k, v in trainset.data[i].items():
#         try:
#             to_str = " ".join(tokenizer.tokenizer.convert_ids_to_tokens(v))
#             #print (to_str)
#             tmp.append(to_str)
#         except:
#             if k == 'aspect_in_text':
#                 v = v.numpy()  # 1-D tensor
#                 #print (v.shape)
#             tmp.append(v)
#         if i <= 0:
#             columns_name.append(k)
#     train_df.append(tmp)
# train_df = pd.DataFrame(train_df,columns=columns_name)

# %%
# check pytorch's model format(that's we need to deliver)
